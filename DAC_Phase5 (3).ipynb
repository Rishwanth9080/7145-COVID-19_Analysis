# %% [markdown]
# **STEP-1: LOADING THE DATASET**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load your dataset
data = pd.read_csv('/content/drive/MyDrive/Certification/covid.csv')
data['date']=data['dateRep']
data
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     31-05-2021   31      5  2021    366       5                 Austria
# 1     30-05-2021   30      5  2021    570       6                 Austria
# 2     29-05-2021   29      5  2021    538      11                 Austria
# 3     28-05-2021   28      5  2021    639       4                 Austria
# 4     27-05-2021   27      5  2021    405      19                 Austria
# ...          ...  ...    ...   ...    ...     ...                     ...
# 2725  06-03-2021    6      3  2021   3455      17                  Sweden
# 2726  05-03-2021    5      3  2021   4069      12                  Sweden
# 2727  04-03-2021    4      3  2021   4884      14                  Sweden
# 2728  03-03-2021    3      3  2021   4876      19                  Sweden
# 2729  02-03-2021    2      3  2021   6191      19                  Sweden
#
#             date
# 0     31-05-2021
# 1     30-05-2021
# 2     29-05-2021
# 3     28-05-2021
# 4     27-05-2021
# ...          ...
# 2725  06-03-2021
# 2726  05-03-2021
# 2727  04-03-2021
# 2728  03-03-2021
# 2729  02-03-2021
#
# [2730 rows x 8 columns]

# %% [markdown]
# **STEP-2:CHECKING FOR NULL VALUES**

# %%
data.isnull().sum()
# Out:
# dateRep                    0
# day                        0
# month                      0
# year                       0
# cases                      0
# deaths                     0
# countriesAndTerritories    0
# date                       0
# dtype: int64

# %% [markdown]
# **STEP-3: DESCRIBING THE DATASET**

# %%
data.describe()
# Out:
#                day        month    year         cases       deaths
# count  2730.000000  2730.000000  2730.0   2730.000000  2730.000000
# mean     16.000000     4.010989  2021.0   3661.010989    65.291941
# std       8.765919     0.818813     0.0   6490.510073   113.956634
# min       1.000000     3.000000  2021.0  -2001.000000    -3.000000
# 25%       8.000000     3.000000  2021.0    361.250000     2.000000
# 50%      16.000000     4.000000  2021.0    926.500000    14.500000
# 75%      24.000000     5.000000  2021.0   3916.250000    72.000000
# max      31.000000     5.000000  2021.0  53843.000000   956.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_0, *['day'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_1, *['month'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_2, *['year'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_3, *['cases'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plot(df, x_colname, y_colname, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(6 * figscale, 6 * figscale))
#   df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha)
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plot(_df_4, *['day', 'month'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plot(df, x_colname, y_colname, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(6 * figscale, 6 * figscale))
#   df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha)
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plot(_df_5, *['month', 'year'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plot(df, x_colname, y_colname, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(6 * figscale, 6 * figscale))
#   df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha)
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plot(_df_6, *['year', 'cases'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plot(df, x_colname, y_colname, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(6 * figscale, 6 * figscale))
#   df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha)
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plot(_df_7, *['cases', 'deaths'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_8, *['year', 'day', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_9, *['year', 'month', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_10, *['year', 'cases', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_11, *['year', 'deaths', None], **{})
# chart
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_12, *['day'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_13, *['month'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_14, *['year'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_15, *['cases'], **{})
# chart

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2730 entries, 0 to 2729
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   dateRep                  2730 non-null   object
#  1   day                      2730 non-null   int64
#  2   month                    2730 non-null   int64
#  3   year                     2730 non-null   int64
#  4   cases                    2730 non-null   int64
#  5   deaths                   2730 non-null   int64
#  6   countriesAndTerritories  2730 non-null   object
#  7   date                     2730 non-null   object
# dtypes: int64(5), object(3)
# memory usage: 170.8+ KB

# %% [markdown]
# **STEP-4: FINDING THE MEAN AND STANDARD DEVIATION OF CASES AND DEATHS**

# %%
case_mean=df['cases'].mean()
case_mean
# Out:
# 3661.010989010989

# %%
death_mean=df['deaths'].mean()
death_mean
# Out:
# 65.29194139194139

# %%
std_cases=df['cases'].std()
std_cases
# Out:
# 6490.510073102118

# %%
std_deaths=df['deaths'].std()
std_deaths
# Out:
# 113.95663405806991

# %%
grouped_data = df.groupby(['year', 'month'])

mean_cases = grouped_data['cases'].mean()
std_cases = grouped_data['cases'].std()

mean_deaths = grouped_data['deaths'].mean()
std_deaths = grouped_data['deaths'].std()

# %% [markdown]
# **STEP-4: VISUALIZING THE MEAN AND STANDARD DEVIATIONS OF CASES AND DEATHS OVER THE TIME PERIOD**

# %%
plt.figure(figsize=(12, 6))
mean_cases.plot(kind='bar', title='Mean Cases by Time Period and Country')
plt.xlabel('Time Period and Country')
plt.ylabel('Mean Cases')
plt.show()

# %%
plt.figure(figsize=(12, 6))
mean_deaths.plot(kind='bar', title='Mean Deaths by Time Period and Country')
plt.xlabel('Time Period and Country')
plt.ylabel('Mean Deaths')
plt.show()

# %%
plt.figure(figsize=(12, 6))
std_cases.plot(kind='bar', title='Standard Deviation of Cases by Time Period and Country')
plt.xlabel('Time Period and Country')
plt.ylabel('Standard Deviation of Cases')
plt.show()

# %%
plt.figure(figsize=(12, 6))
std_deaths.plot(kind='bar', title='Standard Deviation of Deaths by Time Period and Country')
plt.xlabel('Time Period and Country')
plt.ylabel('Standard Deviation of Deaths')
plt.show()

# %% [markdown]
# **STEP-5: VISUALIZING CASES AND DEATHS OVER TIME**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='dateRep', y='cases', label='Cases')
sns.lineplot(data=df, x='dateRep', y='deaths', label='Deaths')
plt.xlabel('Date')
plt.ylabel('Count')
plt.title('COVID-19 Cases and Deaths Over Time')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame with columns: 'date', 'cases', 'deaths'
# Replace 'df' with the name of your DataFrame
# Ensure 'date' is in a datetime format, or convert it using pd.to_datetime if not

plt.figure(figsize=(12, 6))
plt.scatter(df['dateRep'], df['cases'], label='Cases', color='blue')


plt.title('COVID-19 Cases Over Time')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend()
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['dateRep'], df['deaths'], label='Deaths', color='red')

plt.title('COVID-19 Deaths Over Time')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# **STEP-6: COMPARE AND CONTRASTING THE MEAN AND STANDARD DEVIATIONS OF CASES AND DEATHS**

# %%
# Group data by date and calculate mean values
mean_cases = data.groupby('date')['cases'].mean()
mean_deaths = data.groupby('date')['deaths'].mean()

# Create a line plot
plt.figure(figsize=(12, 6))
plt.plot(mean_cases.index, mean_cases, label='Mean Cases', marker='o')
plt.plot(mean_deaths.index, mean_deaths, label='Mean Deaths', marker='o')
plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Mean COVID-19 Cases and Deaths Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate standard deviations
std_cases = data.groupby('date')['cases'].std()
std_deaths = data.groupby('date')['deaths'].std()

# Create a line plot with error bars
plt.figure(figsize=(12, 6))
plt.errorbar(mean_cases.index, mean_cases, yerr=std_cases, label='Cases', marker='o')
plt.errorbar(mean_deaths.index, mean_deaths, yerr=std_deaths, label='Deaths', marker='o')
plt.xlabel('Date')
plt.ylabel('Count')
plt.title('COVID-19 Cases and Deaths with Standard Deviation Error Bars')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **STEP-7: FINDING THE CORRELATION BETWEEN DEATHS AND CASES**

# %%
import seaborn as sns

# Create a correlation matrix
correlation_matrix = data[['cases', 'deaths']].corr()

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation between COVID-19 Cases and Deaths')
plt.show()

# %%
# Visualization : Scatter plot to explore potential correlations
plt.figure(figsize=(10, 6))
plt.scatter(cases, deaths, alpha=0.5)
plt.xlabel('Cases')
plt.ylabel('Deaths')
plt.title('Scatter Plot of COVID-19 Cases vs Deaths')
plt.show()

# %%
import numpy as np
# Calculate Pearson correlation coefficient
correlation = np.corrcoef(cases, deaths)[0, 1]
print(f"Pearson Correlation Coefficient: {correlation:.2f}")
# Out:
# Pearson Correlation Coefficient: 0.77

# %%
# Convert the 'date' column to datetime
data['date'] = pd.to_datetime(data['date'])

# Sort the data by date
data = data.sort_values(by='date')

# Extract cases and deaths
cases = data['cases']
deaths = data['deaths']

# Create a time series plot to visualize the trend
plt.figure(figsize=(12, 6))
plt.plot(data['date'], cases, label='Cases', marker='o', linestyle='-', color='blue')
plt.plot(data['date'], deaths, label='Deaths', marker='o', linestyle='-', color='red')
plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Trend of COVID-19 Cases and Deaths Over Time')
plt.legend()
plt.grid(True)

# Calculate the correlation coefficient between cases and deaths
correlation = cases.corr(deaths)

plt.show()

# Analyze the trend
print(f"Correlation coefficient between cases and deaths: {correlation}")

if correlation > 0.7:
    print("There is a strong positive correlation between cases and deaths.")
elif 0.5 < correlation <= 0.7:
    print("There is a moderate positive correlation between cases and deaths.")
elif 0.3 < correlation <= 0.5:
    print("There is a weak positive correlation between cases and deaths.")
else:
    print("There is little to no correlation between cases and deaths.")
# Out:
# <ipython-input-91-ee048501276e>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['date'] = pd.to_datetime(data['date'])
# Correlation coefficient between cases and deaths: 0.7663088786576354
# There is a strong positive correlation between cases and deaths.

# %% [markdown]
# **STEP-8: BULIDING MACHINE LEARNING MODEL FOR PREDICTING THE DEATHS USING THE MULTI-LINEAR REGRESSION ALGORITHM**

# %%
# Load your dataset
df = pd.read_csv('/content/drive/MyDrive/Certification/covid.csv')
df
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories
# 0     31-05-2021   31      5  2021    366       5                 Austria
# 1     30-05-2021   30      5  2021    570       6                 Austria
# 2     29-05-2021   29      5  2021    538      11                 Austria
# 3     28-05-2021   28      5  2021    639       4                 Austria
# 4     27-05-2021   27      5  2021    405      19                 Austria
# ...          ...  ...    ...   ...    ...     ...                     ...
# 2725  06-03-2021    6      3  2021   3455      17                  Sweden
# 2726  05-03-2021    5      3  2021   4069      12                  Sweden
# 2727  04-03-2021    4      3  2021   4884      14                  Sweden
# 2728  03-03-2021    3      3  2021   4876      19                  Sweden
# 2729  02-03-2021    2      3  2021   6191      19                  Sweden
#
# [2730 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
df['countriesAndTerritories']=label_encoder.fit_transform(df['countriesAndTerritories'])
df
# Out:
#          dateRep  day  month  year  cases  deaths  countriesAndTerritories
# 0     31-05-2021   31      5  2021    366       5                        0
# 1     30-05-2021   30      5  2021    570       6                        0
# 2     29-05-2021   29      5  2021    538      11                        0
# 3     28-05-2021   28      5  2021    639       4                        0
# 4     27-05-2021   27      5  2021    405      19                        0
# ...          ...  ...    ...   ...    ...     ...                      ...
# 2725  06-03-2021    6      3  2021   3455      17                       29
# 2726  05-03-2021    5      3  2021   4069      12                       29
# 2727  04-03-2021    4      3  2021   4884      14                       29
# 2728  03-03-2021    3      3  2021   4876      19                       29
# 2729  02-03-2021    2      3  2021   6191      19                       29
#
# [2730 rows x 7 columns]

# %%
y=df.iloc[:,5].values
y
# Out:
# array([ 5,  6, 11, ..., 14, 19, 19])

# %%
a=df.iloc[:,1:5]
a['countriesAndterritories']=df['countriesAndTerritories']
x=a.values
x
# Out:
# array([[  31,    5, 2021,  366,    0],
#        [  30,    5, 2021,  570,    0],
#        [  29,    5, 2021,  538,    0],
#        ...,
#        [   4,    3, 2021, 4884,   29],
#        [   3,    3, 2021, 4876,   29],
#        [   2,    3, 2021, 6191,   29]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
x_train
# Out:
# array([[   10,     4,  2021,  2734,    11],
#        [   26,     4,  2021,   612,     6],
#        [   27,     5,  2021,   405,     0],
#        ...,
#        [   15,     5,  2021, 17415,     9],
#        [   16,     5,  2021,  1249,    18],
#        [    2,     4,  2021,     0,    28]])

# %%
x_test
# Out:
# array([[  29,    4, 2021,  835,    6],
#        [   3,    4, 2021,  548,   24],
#        [  10,    4, 2021, 5628,   29],
#        ...,
#        [  20,    4, 2021, 1792,    0],
#        [   2,    3, 2021, 6191,   29],
#        [  19,    5, 2021,  732,   18]])

# %%
y_train
# Out:
# array([ 78,   1,  19, ..., 173,   4,   0])

# %%
y_test
# Out:
# array([  2,   9,  16,  19,   0,  23,  60, 351,  24,   2, 217,  15,  17,
#         38,   2,  49,   5,  31,   0,  10,  31,  73,   1,   2,   1, 309,
#         28,   0,   8,  73,  10,   5,   0, 105,   1,  81,  22, 267, 160,
#         90,  67,   0,  11,   6,  46, 228,  12,   0,   7,   3,   2,   9,
#          3, 144, 110,  70,   2,   3,   0,  73,  44,   8, 352, 108, 293,
#         24, 163,  20,  15,  65,  87,  52,   0,   2,   0,  13,  93, 245,
#          0,   2,  36,  82,   9,   1,   0, 221,  16,   3,   1,  37,   9,
#          4, 343, 137, 294,   0,  17, 207, 116, 276, 113,  30, 169,   1,
#          3,  15,  22,   4,   8, 259,   0,  20,  68,  76,  78,   0,   0,
#          7, 307,   4, 187,   0,  18,   7,  65, 264,   0,   0,  66,   0,
#         16,  16,   9,   1,   4,   0, 154,   0,  58, 297,  26,   8,   0,
#         52,  46,   7,  13,  23,  84,  57,   8,  46,  53,   2,   2, 101,
#         26.22218455,  18.21801735,  32.79477738, 100.9466535 ,
#         69.70494799, 348.04605867,  19.77159522,  63.5876815 ,
#         27.19641752,  17.37105981,  85.72085077,  32.92299023,
#        367.83334592,  22.0762328 ,  17.91284597,  30.83079799,
#         41.97136168,  22.72321832,  29.11423773,  19.19649505,
#         16.17058902,  20.27608676,  17.19238293,  26.15293528,
#         18.30827855,  25.70769725,  23.02295479,  24.31136859,
#         39.00518021,  18.89015657,  21.63774371,  26.8502919 ,
#         23.14529455,  32.24871565,  17.03174466,  27.14466565,
#         20.7448388 ,  39.32464248,  23.19132158,  35.42443447,
#         23.06972704, 205.76383364,  81.53547735,  55.83591178,
#         26.13801498,  24.551097  ,  22.97365635,  32.75597158,
#         36.23176469,  62.23759377,  18.51458511,  21.32873164,
#         24.80529715,  94.14190224,  59.77172917,  20.96120966,
#         25.56227257, 172.81391718,  26.07115061,  81.20495823,
#         23.93601411,  17.67456664,  35.59327365,  48.85594929,
#         45.51023223,  36.28994735, 166.87366819,  30.60223916,
#         32.17997647,  18.29512213,  35.36286276,  23.50947815,
#        153.89142559,  26.55459298,  15.20731685,  44.47490704,
#         28.54741993,  34.11433543,  17.02718868,  54.29577874,
#         35.55069413,  54.0533917 ,  18.65235814,  14.35381267,
#         23.00239317,  16.4902632 ,  43.82859668,  20.8201063 ,
#         27.96719141, 184.17657656,  52.71566786,  19.97171417,
#        105.77781587, 383.08305201,  18.87269829,  25.08501472,
#        332.82522136,  70.5942747 ,  18.25268599,  32.03171369,
#        100.48394914,  41.59712855,  70.44457109,  18.57894404,
#         86.05575015,  14.33311553,  72.16701116,  21.98675768,
#         23.27821964,  24.34640403,  19.46961894,  34.48677569,
#        106.04484987,  27.34639818])

# %%
plt.scatter(y_test,y_pred)
plt.show()

# %% [markdown]
# **STEP-9:COMPARING THE ACTUAL VALUE VS PREDICTED VALUE BY FORMING THE TABLE.**

# %%
pred_df=pd.DataFrame({'Actual Value':y_test,'Predicted Value':y_pred,'Difference':y_test-y_pred})
pred_df
# Out:
#      Actual Value  Predicted Value  Difference
# 0               2        22.549380  -20.549380
# 1               9        29.048573  -20.048573
# 2              16        97.708168  -81.708168
# 3              19        48.877380  -29.877380
# 4               0        19.195330  -19.195330
# ..            ...              ...         ...
# 541             1        24.346404  -23.346404
# 542            16        19.469619   -3.469619
# 543            32        34.486776   -2.486776
# 544            19       106.044850  -87.044850
# 545            14        27.346398  -13.346398
#
# [546 rows x 3 columns]

# %% [markdown]
# **STEP-10: FINDING THE METRICS FOR THE CREATED MACHINE LEARNING MODEL AND FINDING THE ACCURACY.**

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.5850794224365943

# %% [markdown]
# **from the above output of r2_score we can observe that the accuracy of the model is 0.5850794224365943 that is 59%**

# %%
from sklearn.metrics import mean_absolute_error
m1= mean_absolute_error(y_test,y_pred)
m1
# Out:
# 38.48406962534945

# %%
from sklearn.metrics import mean_squared_error
m2=mean_squared_error(y_test,y_pred)
m2
# Out:
# 4584.042685668658
